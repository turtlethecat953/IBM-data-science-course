# %% [markdown]
# <h1>London-Paris-compare</h1>

# %% [markdown]
# <h1>Introduction and Business Problem</h1>
#
# London and Paris are two of the most ancient city in the world. This project is aim to try to analysis the two cities, more specificly I aimed to analysis how the cities can be seperated to several section(cluster) with similar shops and facilities. By doing so, I belive we can have betting understanding of the two cities. The Reason for choosing London and Paris is becasue both cities have a lot of data availabe to the public and make it very easy to collect data for both of the cities.

# %% [markdown]
# <h1>Data Description</h1>
#
# <h2>London</h2>
#
# I get the data from https://en.wikipedia.org/wiki/List_of_London_boroughs
#
# The dataframe contain data of Londa consist:
# 1. Borough : Name of Borough
# 2. Latitude : Latitude
# 3. Longitude : Longitude
#
# <h2>Paris</h2>
#
# I get the data from https://en.wikipedia.org/wiki/Arrondissements_of_Paris and from https://www.data.gouv.fr/fr/datasets/r/e88c6fda-1d09-42a0-a069-606d3259114e.
#
# I preprocess the data into a cvs file already.
#
# The dataframe contain data of Londa consist:
# 1. District : Name of District
# 2. Latitude : Latitude
# 3. Longitude : Longitude
#
# <h2>Foursquare API Data</h2>
#
# I will get data from foursquare API to analysis each distrinct in London and in Paris

# %%
import requests
import pandas as pd
import numpy as np
import urllib.request
from geopy.geocoders import Nominatim
import folium
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans

# %%
CLIENT_ID = '32MVT5TKDCXDFDDR0DUTZTUKTE1J02ZOCSTRSFZ4V3RTV5VN' # your Foursquare ID
CLIENT_SECRET = 'POM4TH0RJ3U0NAEHV4VLSNGS2RGS2Q0BMWYXPF10AVXANF1E' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

# %%
## URL to extract City neighbourhood information
urlL = "https://en.wikipedia.org/wiki/List_of_London_boroughs"
pageLondon = urllib.request.urlopen(urlL)
wikitablesL = pd.read_html(urlL,  attrs={"class":"wikitable"})
dfL0 = wikitablesL[0]
dfL1 = wikitablesL[1]

# %%
dfL0=dfL0.rename(columns={'Population (2019 est)[1]':'Population(2019 est)',}).drop(columns=['Nr. in map'])
dfL1=dfL1.drop(columns=['Nr. inmap'])
dfl=pd.concat([dfL0,dfL1]).reset_index().drop(columns=['index'])
dfl=dfl.drop(columns=['Inner','Status','Local authority','Political control','Headquarters','Area (sq mi)','Population(2019 est)'])
dfl['Co-ordinates'][0]='51.5607°N 0.1557°E'
lat_list=[51.5607]
log_list=[0.1557]
for i in range(1,dfl.shape[0]):
    index=dfl['Co-ordinates'][i].find('/')
    dfl['Co-ordinates'][i]=dfl['Co-ordinates'][i][index+1:]
    coord=dfl['Co-ordinates'][i].split(' ')
    lat=float(coord[1][:8].encode('utf-8').decode('utf-8-sig'))
    if coord[2][-1]=='W':
        flag=-1
    else:
        flag=1
    log=flag*float(coord[2][:6])
    lat_list.append(lat)
    log_list.append(log)
dfl['Latitude']=lat_list
dfl['Longitude']=log_list
dfl.drop(columns=['Co-ordinates'],inplace=True)
dfl.loc[0,'Borough']='Barking and Dagenham'
dfl.loc[9,'Borough']='Greenwich'
dfl.loc[11,'Borough']='Hammersmith and Fulham'
dfl.head()
# Out:
#                 Borough  Latitude  Longitude
# 0  Barking and Dagenham   51.5607     0.1557
# 1                Barnet   51.6252    -0.1517
# 2                Bexley   51.4549     0.1505
# 3                 Brent   51.5588    -0.2817
# 4               Bromley   51.4039     0.0198

# %%
dfp=pd.read_csv(R"C:\Users\lautszchun\Desktop\projects_and_resources\coursera-data-science\London-Paris-camparison\Paris-data.csv")
dfp.head()
# Out:
#    postal_code        district nom_dept   Latitude  Longitude
# 0        75001          Louvre    PARIS  48.862630   2.336293
# 1        75002          Bourse    PARIS  48.867903   2.344107
# 2        75003          Temple    PARIS  48.863054   2.359361
# 3        75004  Hotel-de-Ville    PARIS  48.854228   2.357362
# 4        75005        Pantheon    PARIS  48.844509   2.349859

# %%
address = 'London'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
london_latitude = location.latitude
london_longitude = location.longitude

map_london = folium.Map(location=[london_latitude, london_longitude], zoom_start=10)

for lat, lng, borough in zip(dfl['Latitude'],dfl['Longitude'],dfl['Borough']):
    label = '{}'.format(borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='red',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_london)  
    
map_london
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_4e93384faac54b4293a35190754ddb3d%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_4e93384faac54b4293a35190754ddb3d%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_4e93384faac54b4293a35190754ddb3d%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_4e93384faac54b4293a35190754ddb3d%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B51.5073219%2C-0.1276474%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%20 ...

# %%
address = 'Paris'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
paris_latitude = location.latitude
paris_longitude = location.longitude

map_paris = folium.Map(location=[paris_latitude, paris_longitude], zoom_start=12)

for lat, lng, borough in zip(dfp['Latitude'],dfp['Longitude'],dfp['district']):
    label = '{}'.format(borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_paris)  
    
map_paris
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_ab9cc9ded60a4432a5e79bd445f6e728%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_ab9cc9ded60a4432a5e79bd445f6e728%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_ab9cc9ded60a4432a5e79bd445f6e728%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_ab9cc9ded60a4432a5e79bd445f6e728%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B48.8566969%2C2.3514616%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2012%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%20% ...

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
London_venues=getNearbyVenues(dfl['Borough'],dfl['Latitude'],dfl['Longitude'])

# %%
Paris_venues = getNearbyVenues(dfp['district'],dfp['Latitude'],dfp['Longitude'])

# %%
# one hot encoding
london_onehot = pd.get_dummies(London_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
london_onehot['Neighborhood'] = London_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [london_onehot.columns[-1]] + list(london_onehot.columns[:-1])
london_onehot = london_onehot[fixed_columns]

# one hot encoding
paris_onehot = pd.get_dummies(Paris_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
paris_onehot['Neighborhood'] = Paris_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [paris_onehot.columns[-1]] + list(paris_onehot.columns[:-1])
paris_onehot = paris_onehot[fixed_columns]

# %% [markdown]
# <h2> Showing the top 5 venue in London</h2>

# %%
ld_venue_count=London_venues['Venue Category'].value_counts()
ld_venue_count[:5].plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='Venue Category'>

# %% [markdown]
# <h2> Showing the top 5 venue in Paris</h2>

# %%
pr_venue_count=Paris_venues['Venue Category'].value_counts()
pr_venue_count[:5].plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='Venue Category'>

# %%
london_grouped = london_onehot.groupby('Neighborhood').mean().reset_index()
paris_grouped = paris_onehot.groupby('Neighborhood').mean().reset_index()

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)

    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Borough']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
london_venues_sorted = pd.DataFrame(columns=columns)
london_venues_sorted['Borough'] = london_grouped['Neighborhood']

for ind in np.arange(london_grouped.shape[0]):
    london_venues_sorted.iloc[ind, 1:] = return_most_common_venues(london_grouped.iloc[ind, :], num_top_venues)

columns = ['district']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))    
    
paris_venues_sorted = pd.DataFrame(columns=columns)
paris_venues_sorted['district'] = paris_grouped['Neighborhood']

for ind in np.arange(paris_grouped.shape[0]):
    paris_venues_sorted.iloc[ind, 1:] = return_most_common_venues(paris_grouped.iloc[ind, :], num_top_venues)

# %%
k=3
london_grouped_clustering = london_grouped.drop('Neighborhood', 1)
london_kmeans = KMeans(n_clusters=k, random_state=0).fit(london_grouped_clustering)

paris_grouped_clustering = paris_grouped.drop('Neighborhood', 1)
paris_kmeans = KMeans(n_clusters=k, random_state=0).fit(paris_grouped_clustering)

# %%
london_venues_sorted.insert(0, 'Cluster Labels', london_kmeans.labels_)

london_merged = dfl

london_merged = london_merged.join(london_venues_sorted.set_index('Borough'), on='Borough')

london_merged.head()
# Out:
#                 Borough  Latitude  Longitude  Cluster Labels  \
# 0  Barking and Dagenham   51.5607     0.1557               1
# 1                Barnet   51.6252    -0.1517               2
# 2                Bexley   51.4549     0.1505               1
# 3                 Brent   51.5588    -0.2817               1
# 4               Bromley   51.4039     0.0198               1
#
#   1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 0  Gym / Fitness Center                  Park           Supermarket
# 1                  Café              Bus Stop          Home Service
# 2                   Pub        Clothing Store           Supermarket
# 3           Coffee Shop                 Hotel   Sporting Goods Shop
# 4        Clothing Store           Coffee Shop           Pizza Place
#
#   4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 0           Golf Course   Martial Arts School           Bus Station
# 1    African Restaurant      Pedestrian Plaza             Nightclub
# 2           Coffee Shop  Fast Food Restaurant              Pharmacy
# 3        Clothing Store                   Bar     Indian Restaurant
# 4  Gym / Fitness Center          Burger Joint                   Bar
#
#     7th Most Common Venue 8th Most Common Venue    9th Most Common Venue  \
# 0                    Pool            Playground  New American Restaurant
# 1  Okonomiyaki Restaurant          Optical Shop          Organic Grocery
# 2   Portuguese Restaurant                Bakery       Chinese Restaurant
# 3          Sandwich Place         Grocery Store      American Restaurant
# 4      English Restaurant                  Café         Stationery Store
#
#   10th Most Common Venue
# 0              Nightclub
# 1      Outdoor Sculpture
# 2          Shopping Mall
# 3             Restaurant
# 4         Chocolate Shop

# %%
paris_venues_sorted.insert(0, 'Cluster Labels', paris_kmeans.labels_)

paris_merged = dfp

paris_merged = paris_merged.join(paris_venues_sorted.set_index('district'), on='district')

paris_merged.head()
# Out:
#    postal_code        district nom_dept   Latitude  Longitude  Cluster Labels  \
# 0        75001          Louvre    PARIS  48.862630   2.336293               0
# 1        75002          Bourse    PARIS  48.867903   2.344107               0
# 2        75003          Temple    PARIS  48.863054   2.359361               0
# 3        75004  Hotel-de-Ville    PARIS  48.854228   2.357362               0
# 4        75005        Pantheon    PARIS  48.844509   2.349859               0
#
#   1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 0     French Restaurant                 Hotel                 Plaza
# 1     French Restaurant          Cocktail Bar                Bakery
# 2     French Restaurant           Coffee Shop          Gourmet Shop
# 3     French Restaurant        Ice Cream Shop        Clothing Store
# 4     French Restaurant                 Hotel                Bakery
#
#   4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 0   Japanese Restaurant            Art Museum           Coffee Shop
# 1           Coffee Shop              Creperie    Italian Restaurant
# 2   Japanese Restaurant    Italian Restaurant                Bakery
# 3                 Hotel                  Park              Wine Bar
# 4    Italian Restaurant                 Plaza                  Café
#
#   7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 0    Italian Restaurant                  Café         Historic Site
# 1              Wine Bar                 Hotel         Women's Store
# 2           Art Gallery        Sandwich Place              Wine Bar
# 3                 Plaza      Pedestrian Plaza           Pastry Shop
# 4                   Pub           Coffee Shop        Science Museum
#
#   10th Most Common Venue
# 0            Cheese Shop
# 1       Pedestrian Plaza
# 2           Burger Joint
# 3            Art Gallery
# 4       Greek Restaurant

# %% [markdown]
# <h1>Showing the Clusters of London</h1>

# %%
# create map
london_map_clusters = folium.Map(location=[london_latitude, london_longitude], zoom_start=10)

# set color scheme for the clusters
x = np.arange(k)
ys = [i + x + (i*x)**2 for i in range(k)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(london_merged['Latitude'], london_merged['Longitude'], london_merged['Borough'], london_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(london_map_clusters)
       
london_map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_26117c21d8824b8bb49e7a76b5e00268%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_26117c21d8824b8bb49e7a76b5e00268%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_26117c21d8824b8bb49e7a76b5e00268%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_26117c21d8824b8bb49e7a76b5e00268%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B51.5073219%2C-0.1276474%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%20 ...

# %% [markdown]
# <h1>Showing the Clusters of Paris</h1>

# %%
# create map
paris_map_clusters = folium.Map(location=[paris_latitude, paris_longitude], zoom_start=12)

# set color scheme for the clusters
x = np.arange(k)
ys = [i + x + (i*x)**2 for i in range(k)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(paris_merged['Latitude'], paris_merged['Longitude'], paris_merged['district'], paris_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(paris_map_clusters)
       
paris_map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_c56f6aba15eb4f34a6d8872c727683af%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_c56f6aba15eb4f34a6d8872c727683af%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_c56f6aba15eb4f34a6d8872c727683af%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_c56f6aba15eb4f34a6d8872c727683af%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B48.8566969%2C2.3514616%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2012%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%20% ...

# %%
(london_merged.loc[london_merged['Cluster Labels'] == 0])
# Out:
#      Borough  Latitude  Longitude  Cluster Labels 1st Most Common Venue  \
# 16  Hounslow   51.4746     -0.368               0       Bed & Breakfast
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 16                  Café                  Park    Chinese Restaurant
#
#    5th Most Common Venue 6th Most Common Venue   7th Most Common Venue  \
# 16    African Restaurant             Nightclub  Okonomiyaki Restaurant
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 16          Optical Shop       Organic Grocery      Outdoor Sculpture

# %%
(london_merged.loc[london_merged['Cluster Labels'] == 1])
# Out:
#                    Borough  Latitude  Longitude  Cluster Labels  \
# 0     Barking and Dagenham   51.5607     0.1557               1
# 2                   Bexley   51.4549     0.1505               1
# 3                    Brent   51.5588    -0.2817               1
# 4                  Bromley   51.4039     0.0198               1
# 5                   Camden   51.5290    -0.1255               1
# 6                  Croydon   51.3714    -0.0977               1
# 7                   Ealing   51.5130    -0.3089               1
# 8                  Enfield   51.6538    -0.0799               1
# 9                Greenwich   51.4892     0.0648               1
# 10                 Hackney   51.5450    -0.0553               1
# 11  Hammersmith and Fulham   51.4927    -0.2339               1
# 12                Haringey   51.6000    -0.1119               1
# 13                  Harrow   51.5898    -0.3346               1
# 14                Havering   51.5812     0.1837               1
# 15              Hillingdon   51.5441    -0.4760               1
# 17               Islington   51.5416    -0.1022               1
# 18  Kensington and Chelsea   51.5020    -0.1947               1
# 19    Kingston upon Thames   51.4085    -0.3064               1
# 20                 Lambeth   51.4607    -0.1163               1
# 21                Lewisham   51.4452    -0.0209               1
# 22                  Merton   51.4014    -0.1958               1
# 23                  Newham   51.5077     0.0469               1
# 24               Redbridge   51.5590     0.0741               1
# 25    Richmond upon Thames   51.4479    -0.3260               1
# 26               Southwark   51.5035    -0.0804               1
# 27                  Sutton   51.3618    -0.1945               1
# 28           Tower Hamlets   51.5099    -0.0059               1
# 29          Waltham Forest   51.5908    -0.0134               1
# 30              Wandsworth   51.4567    -0.1910               1
# 31             Westminster   51.4973    -0.1372               1
# 32          City of London   51.5155    -0.0922               1
#
#    1st Most Common Venue          2nd Most Common Venue  \
# 0   Gym / Fitness Center                           Park
# 2                    Pub                 Clothing Store
# 3            Coffee Shop                          Hotel
# 4         Clothing Store                    Coffee Shop
# 5            Coffee Shop                           Café
# 6                    Pub                    Coffee Shop
# 7            Coffee Shop                 Clothing Store
# 8         Clothing Store                    Coffee Shop
# 9                    Pub                    Supermarket
# 10                   Pub                    Coffee Shop
# 11                   Pub                           Café
# 12                  Park                           Café
# 13              Platform              Indian Restaurant
# 14           Coffee Shop                          Hotel
# 15           Coffee Shop                 Clothing Store
# 17                   Pub                           Park
# 18                Bakery                           Café
# 19           Coffee Shop                           Café
# 20  Caribbean Restaurant                    Coffee Shop
# 21           Supermarket                  Grocery Store
# 22                 Diner                           Café
# 23                 Hotel                Airport Service
# 24  Fast Food Restaurant                    Supermarket
# 25                   Pub                    Coffee Shop
# 26           Coffee Shop                            Pub
# 27        Clothing Store                            Pub
# 28           Coffee Shop           Gym / Fitness Center
# 29                   Pub  Vegetarian / Vegan Restaurant
# 30                   Pub                    Coffee Shop
# 31                 Hotel                    Coffee Shop
# 32           Coffee Shop              French Restaurant
#
#     3rd Most Common Venue 4th Most Common Venue  5th Most Common Venue  \
# 0             Supermarket           Golf Course    Martial Arts School
# 2             Supermarket           Coffee Shop   Fast Food Restaurant
# 3     Sporting Goods Shop        Clothing Store                    Bar
# 4             Pizza Place  Gym / Fitness Center           Burger Joint
# 5                   Hotel                   Pub          Deli / Bodega
# 6   Portuguese Restaurant  Caribbean Restaurant         Clothing Store
# 7                    Park                Bakery                    Pub
# 8                     Pub           Supermarket       Department Store
# 9    Fast Food Restaurant        Clothing Store            Coffee Shop
# 10                Brewery                Bakery           Cocktail Bar
# 11     Italian Restaurant     Indian Restaurant            Coffee Shop
# 12     Italian Restaurant                Bakery  Portuguese Restaurant
# 13          Grocery Store   Indie Movie Theater            Supermarket
# 14          Shopping Mall        Clothing Store       Department Store
# 15   Fast Food Restaurant                   Pub               Pharmacy
# 17                Theater           Music Venue                 Bakery
# 18              Juice Bar            Restaurant                  Hotel
# 19         Clothing Store                   Pub     Italian Restaurant
# 20                    Pub                Market               Beer Bar
# 21            Coffee Shop    Italian Restaurant               Platform
# 22            Supermarket                Bakery            Pizza Place
# 23         Sandwich Place              Pharmacy         Airport Lounge
# 24         Clothing Store         Grocery Store       Department Store
# 25     Italian Restaurant         Grocery Store               Pharmacy
# 26                    Bar        Scenic Lookout           Cocktail Bar
# 27            Coffee Shop                  Café     Italian Restaurant
# 28     Italian Restaurant                 Hotel         Sandwich Place
# 29           Concert Hall  Gym / Fitness Center             Beer Store
# 30         Clothing Store     Indian Restaurant         Breakfast Spot
# 31         Sandwich Place               Theater     Italian Restaurant
# 32                  Hotel            Steakhouse         Clothing Store
#
#    6th Most Common Venue  7th Most Common Venue    8th Most Common Venue  \
# 0            Bus Station                   Pool               Playground
# 2               Pharmacy  Portuguese Restaurant                   Bakery
# 3      Indian Restaurant         Sandwich Place            Grocery Store
# 4                    Bar     English Restaurant                     Café
# 5           Burger Joint     Italian Restaurant           Sandwich Place
# 6              Nightclub            Gaming Cafe         Greek Restaurant
# 7     Italian Restaurant   Gym / Fitness Center             Burger Joint
# 8           Optical Shop       Stationery Store                 Pharmacy
# 9                  Hotel          Grocery Store                    Plaza
# 10       Organic Grocery                   Café                    Hotel
# 11                 Hotel              Gastropub    Vietnamese Restaurant
# 12     Convenience Store   Fast Food Restaurant            Movie Theater
# 13           Coffee Shop        Thai Restaurant  New American Restaurant
# 14                   Pub              Bookstore     Fast Food Restaurant
# 15      Department Store           Burger Joint       Italian Restaurant
# 17          Burger Joint               Boutique           Ice Cream Shop
# 18        Clothing Store            Art Gallery       Italian Restaurant
# 19                Bakery       Department Store         Sushi Restaurant
# 20  Gym / Fitness Center            Pizza Place     Brazilian Restaurant
# 21         Train Station          Shopping Mall         Greek Restaurant
# 22        Sandwich Place            Coffee Shop     Fast Food Restaurant
# 23               Airport                Rafting       Chinese Restaurant
# 24                Bakery         Sandwich Place              Coffee Shop
# 25     Indian Restaurant               Platform            Deli / Bodega
# 26            Restaurant      French Restaurant                    Hotel
# 27        Sandwich Place       Department Store                      Bar
# 28                  Café              Wine Shop        Outdoor Sculpture
# 29              Tea Room            Pizza Place              Coffee Shop
# 30           Supermarket       Asian Restaurant     Gym / Fitness Center
# 31      Sushi Restaurant                    Pub                Juice Bar
# 32              Wine Bar     Seafood Restaurant              Art Gallery
#
#       9th Most Common Venue      10th Most Common Venue
# 0   New American Restaurant                   Nightclub
# 2        Chinese Restaurant               Shopping Mall
# 3       American Restaurant                  Restaurant
# 4          Stationery Store              Chocolate Shop
# 5             Train Station                 Pizza Place
# 6                      Café                   Bookstore
# 7                     Hotel                        Café
# 8                 Gift Shop                   Bookstore
# 9                  Pharmacy              Breakfast Spot
# 10            Grocery Store  Modern European Restaurant
# 11              Pizza Place              Cosmetics Shop
# 12              Supermarket               Grocery Store
# 13                Nightclub      Okonomiyaki Restaurant
# 14                     Café                      Bakery
# 15         Toy / Game Store                   Gift Shop
# 17              Fish Market             Organic Grocery
# 18        French Restaurant                Burger Joint
# 19             Burger Joint             Thai Restaurant
# 20       Italian Restaurant          Mexican Restaurant
# 21    Portuguese Restaurant                    Bus Stop
# 22                     Park                Optical Shop
# 23       Light Rail Station                 Outlet Mall
# 24                      Pub        Gym / Fitness Center
# 25              Pizza Place        Fast Food Restaurant
# 26        Indian Restaurant             Thai Restaurant
# 27        French Restaurant                   Multiplex
# 28       Chinese Restaurant               Grocery Store
# 29                    Field                 Art Gallery
# 30                 Pharmacy                 Pizza Place
# 31      Sporting Goods Shop                   Hotel Bar
# 32     Gym / Fitness Center          Italian Restaurant

# %%
(london_merged.loc[london_merged['Cluster Labels'] == 2])
# Out:
#   Borough  Latitude  Longitude  Cluster Labels 1st Most Common Venue  \
# 1  Barnet   51.6252    -0.1517               2                  Café
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 1              Bus Stop          Home Service    African Restaurant
#
#   5th Most Common Venue 6th Most Common Venue   7th Most Common Venue  \
# 1      Pedestrian Plaza             Nightclub  Okonomiyaki Restaurant
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 1          Optical Shop       Organic Grocery      Outdoor Sculpture

# %%
paris_merged.loc[paris_merged['Cluster Labels'] == 0]
# Out:
#     postal_code             district nom_dept   Latitude  Longitude  \
# 0         75001               Louvre    PARIS  48.862630   2.336293
# 1         75002               Bourse    PARIS  48.867903   2.344107
# 2         75003               Temple    PARIS  48.863054   2.359361
# 3         75004       Hotel-de-Ville    PARIS  48.854228   2.357362
# 4         75005             Pantheon    PARIS  48.844509   2.349859
# 5         75006           Luxembourg    PARIS  48.848968   2.332671
# 6         75007       Palais-Bourbon    PARIS  48.856083   2.312439
# 7         75008               Elysse    PARIS  48.872527   2.312583
# 8         75009                Opera    PARIS  48.876896   2.337460
# 9         75010             Entrepot    PARIS  48.876029   2.361113
# 10        75011           Popincourt    PARIS  48.859415   2.378741
# 12        75013             Gobelins    PARIS  48.828718   2.362468
# 13        75014         Observatoire    PARIS  48.828993   2.327101
# 14        75015            Vaugirard    PARIS  48.840155   2.293559
# 16        75017  Batignolles-Monceau    PARIS  48.887337   2.307486
# 17        75018     Butte-Montmartre    PARIS  48.892735   2.348712
# 18        75019      Buttes-Chaumont    PARIS  48.886869   2.384694
# 19        75020         Menilmontant    PARIS  48.863187   2.400820
#
#     Cluster Labels  1st Most Common Venue 2nd Most Common Venue  \
# 0                0      French Restaurant                 Hotel
# 1                0      French Restaurant          Cocktail Bar
# 2                0      French Restaurant           Coffee Shop
# 3                0      French Restaurant        Ice Cream Shop
# 4                0      French Restaurant                 Hotel
# 5                0                 Bakery        Chocolate Shop
# 6                0                  Hotel     French Restaurant
# 7                0      French Restaurant                 Hotel
# 8                0      French Restaurant                 Hotel
# 9                0      French Restaurant                Bistro
# 10               0             Restaurant    Italian Restaurant
# 12               0  Vietnamese Restaurant      Asian Restaurant
# 13               0      French Restaurant                Bakery
# 14               0     Italian Restaurant                 Hotel
# 16               0                  Hotel     French Restaurant
# 17               0      French Restaurant                   Bar
# 18               0      French Restaurant                   Bar
# 19               0                 Bakery                Bistro
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0                  Plaza   Japanese Restaurant            Art Museum
# 1                 Bakery           Coffee Shop              Creperie
# 2           Gourmet Shop   Japanese Restaurant    Italian Restaurant
# 3         Clothing Store                 Hotel                  Park
# 4                 Bakery    Italian Restaurant                 Plaza
# 5            Pastry Shop     French Restaurant              Fountain
# 6     Italian Restaurant                  Café                 Plaza
# 7                    Spa                Bakery      Toy / Game Store
# 8                 Bistro   Japanese Restaurant              Wine Bar
# 9                  Hotel                  Café           Coffee Shop
# 10                  Café                Bakery     French Restaurant
# 12    Chinese Restaurant       Thai Restaurant     French Restaurant
# 13   Japanese Restaurant                Bistro                 Hotel
# 14     French Restaurant                 Plaza                  Park
# 16    Italian Restaurant   Japanese Restaurant                  Café
# 17    Italian Restaurant                 Plaza           Pizza Place
# 18                Bistro            Playground           Supermarket
# 19   Japanese Restaurant                 Plaza     French Restaurant
#
#          6th Most Common Venue 7th Most Common Venue   8th Most Common Venue  \
# 0                  Coffee Shop    Italian Restaurant                    Café
# 1           Italian Restaurant              Wine Bar                   Hotel
# 2                       Bakery           Art Gallery          Sandwich Place
# 3                     Wine Bar                 Plaza        Pedestrian Plaza
# 4                         Café                   Pub             Coffee Shop
# 5           Athletics & Sports              Tea Room                   Plaza
# 6               History Museum          Cocktail Bar              Art Museum
# 7   Modern European Restaurant             Hotel Bar  Furniture / Home Store
# 8                 Cocktail Bar                Lounge                  Bakery
# 9           Italian Restaurant           Pizza Place       Indian Restaurant
# 10       Vietnamese Restaurant                   Bar             Pastry Shop
# 12                       Hotel             Juice Bar                Bus Stop
# 13                  Laundromat             Brasserie        Sushi Restaurant
# 14             Thai Restaurant     Indian Restaurant                  Bistro
# 16                      Bakery            Restaurant                   Plaza
# 17                       Hotel            Restaurant                  Bistro
# 18          Seafood Restaurant              Beer Bar                   Hotel
# 19                         Bar                  Café      Italian Restaurant
#
#      9th Most Common Venue     10th Most Common Venue
# 0            Historic Site                Cheese Shop
# 1            Women's Store           Pedestrian Plaza
# 2                 Wine Bar               Burger Joint
# 3              Pastry Shop                Art Gallery
# 4           Science Museum           Greek Restaurant
# 5        Outdoor Sculpture                 Shoe Store
# 6      Japanese Restaurant                     Bistro
# 7            Grocery Store        Corsican Restaurant
# 8               Restaurant         Turkish Restaurant
# 9         Asian Restaurant        Japanese Restaurant
# 10  Gluten-free Restaurant  South American Restaurant
# 12             Coffee Shop       Cambodian Restaurant
# 13       Food & Drink Shop                   Tea Room
# 14     Japanese Restaurant                Coffee Shop
# 16       Korean Restaurant                     Bistro
# 17                    Café          Convenience Store
# 18                    Café                Music Store
# 19                   Hotel                       Park

# %%
paris_merged.loc[paris_merged['Cluster Labels'] == 1]
# Out:
#     postal_code district nom_dept   Latitude  Longitude  Cluster Labels  \
# 15        75016    Passy    PARIS  48.860399     2.2621               1
#
#    1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 15                  Lake                 Plaza           Bus Station
#
#    4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 15            Art Museum         Boat or Ferry              Bus Stop
#
#    7th Most Common Venue 8th Most Common Venue  9th Most Common Venue  \
# 15     French Restaurant                  Park  Performing Arts Venue
#
#     10th Most Common Venue
# 15  Okonomiyaki Restaurant

# %%
paris_merged.loc[paris_merged['Cluster Labels'] == 2]
# Out:
#     postal_code district nom_dept   Latitude  Longitude  Cluster Labels  \
# 11        75012  Reuilly    PARIS  48.835156   2.419807               2
#
#    1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 11           Zoo Exhibit                   Zoo           Supermarket
#
#    4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 11   Monument / Landmark                Bistro      Pedestrian Plaza
#
#    7th Most Common Venue 8th Most Common Venue   9th Most Common Venue  \
# 11             Nightclub          Noodle House  Okonomiyaki Restaurant
#
#    10th Most Common Venue
# 11           Optical Shop

# %% [markdown]
# <h1>Final Conculsion</h1>
#
# As shown in the two cluster map of London and Paris, In fact most of the boroughs or districts in each city are quite similar with only some outliners that differ from the rest.
#
# In London, Hounslow and Barnet are the outliner.
# In Paris, Passy and Reuilly are the outliner.
